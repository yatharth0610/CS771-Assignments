# %%
## Library Imports (Numpy, Matplotlib)

import numpy as np
import time
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
# %matplotlib inline

# %% [markdown]
# # Question 1
#
# This question demanded us to study the gradient descent algorithm and implement it's various use-cases as well as compare between it's different flavours.

# %%
def gradient_descent(gradient, init_, learn_rate, n_iter=50, tol=1e-6):
    x = init_
    for _ in range(n_iter):
        delta = -learn_rate * gradient(x)
        if np.all(np.abs(delta) <= tol):
            break
        x += delta
    return round(x*1000)/1000

# %% [markdown]
# ## Part 1(a)

# %%
## (i) x^2 + 3x + 4 

## Let's visualise the plot first
x = np.linspace(-5, 5, 1000)
y = x**2 + 3*x + 4

fig = plt.figure(figsize = (10, 5))
plt.plot(x, y)
plt.show()

# %% [markdown]
# Gradient descent on $x^2+3x+4$. The derivative of $x^2+3x+4$ is $2x+3$, which is passed as arguement of gradient desecent function. Different pairs of learning_rate, n_iters are tried to see what is the optimal minima.

# %%
## Starting gradient descent from x = 1, with learning rate as 0

## Custom gradient function
def gradient1(x):
    return 2*x + 3

## Playing with lr and n_iters
minima1 = gradient_descent(gradient1, 1, 0.01)
minima2 = gradient_descent(gradient1, 1, 0.01, 500)
minima3 = gradient_descent(gradient1, 1, 0.05)
minima4 = gradient_descent(gradient1, 1, 0.05, 500)

print(minima1)
print(minima2)
print(minima3)
print(minima4)
# Out:
# -0.59
# -1.5
# -1.487
# -1.5

# %% [markdown]
# We can safely conclude that different initialisations will need different learning rates and number of iterations to find the minima, hence it becomes important to choose them accordingly. However, most of the initial points have converged to local minima i.e. $\frac{-b}{a}$ for the quadratic function which is consistent with our results.
#
# Conclusion : There is one minima at $x = -1.5$

# %%
## (ii) x^4 - 3x^2 + 2x

## Visualising the plot 
x = np.linspace(-5, 5, 1000) # since derivative is monotone for ranges beyond +5 and -5
y = x**4 - 3*x*x + 2*x

fig = plt.figure(figsize = (10, 10))
plt.plot(x, y)
plt.show()

# %%
## Magnifying the plot in the range -3, 3

x = np.linspace(-3, 3, 1000)
y = x**4 - 3*x*x + 2*x

fig = plt.figure(figsize = (10, 10))
plt.plot(x, y)
plt.show()

# %% [markdown]
# Gradient descent on $x^4-3x^2+2x$. The derivative of $x^4-3x^2+2x$ is $4x^3-6x+2$, which is passed as arguement of gradient desecent function. Learn rate set to 0.001 (a small learn rate because the derivatives are large and this can lead to longer learning or overflow issues) and 100-500 iterations.

# %%
## A good starting point for finding global minima maybe -0.5 or -1 (for faster convergence)

def gradient2(x):
    return 4*(x**3) - 6*x + 2

## Playing with lr and n_iters
minima1 = gradient_descent(gradient2, -0.5, 0.001, 100)
minima2 = gradient_descent(gradient2, -0.5, 0.001, 500)
minima3 = gradient_descent(gradient2, -0.5, 0.002, 100)
minima4 = gradient_descent(gradient2, -0.5, 0.002, 500)

print(minima1)
print(minima2)
print(minima3)
print(minima4)
# Out:
# -0.966
# -1.365
# -1.257
# -1.366

# %% [markdown]
# Similar to the previous case, we can see that different learning rates
# can lead to slower or faster convergence. When increasing the number of iterations all of the minimas are almost same, while they are quite different with less number of iterations. Let's test some more to confirm the minimas.

# %%
## We can also find the second local minima, if we start the GD algorithm 
## a number greater than 1

for i in range(10):
    minima = gradient_descent(gradient2, i, 0.001, 1000)
    print(f"Minima for initial value %d is %d" %(i, minima))
# Out:
# Minima for initial value 0 is -1
# Minima for initial value 1 is 1
# Minima for initial value 2 is 1
# Minima for initial value 3 is 1
# Minima for initial value 4 is 1
# Minima for initial value 5 is 1
# Minima for initial value 6 is 1
# Minima for initial value 7 is 1
# Minima for initial value 8 is 1
# Minima for initial value 9 is 1

# %% [markdown]
# We can see that 0 gives another minima as compared to 1-9
# On checking for x = 1. Derivative at $x = 1$ is $4-6+2 = 0$ (one of the minimas).

# %%
## Looking at the graph, we can also try for negative integers, they
## all should converge to the global minima

for i in range(10):
    minima = gradient_descent(gradient2, -i, 0.001, 1000)
    print(f"Minima for initial value " + str(-i) + " is " + str(minima))
# Out:
# Minima for initial value 0 is -1.366
# Minima for initial value -1 is -1.366
# Minima for initial value -2 is -1.366
# Minima for initial value -3 is -1.366
# Minima for initial value -4 is -1.366
# Minima for initial value -5 is -1.366
# Minima for initial value -6 is -1.366
# Minima for initial value -7 is -1.366
# Minima for initial value -8 is -1.366
# Minima for initial value -9 is -1.366

# %% [markdown]
# We can see that all of them converge to the same minimum value which is also kind of apparent looking at the graph we have plotted. Existence of any other optima can be denied since the derivative will be a cubic and we can already see the three optimas in the region we have plotted (2 minimas and 1 maxima).

# %%
## Confirming that which of the following is global minima

def foo(x):
    return (x**4 - 3*(x**2) + 2*x)

print(foo(-1.366))
print(foo(1))
# Out:
# -4.848076206064
# 0

# %% [markdown]
# Hence, for this function there are two minimas. A global minima at $x = -1.366$ and a local minima at $x = 1$.

# %% [markdown]
# ## Part 1(b)
#
# For this part, I have assumed the error to be MSE. Hence the gradient has been computed as follows
#
# $$L = \frac{1}{n}\sum_{i = 0}^{i = n} (y_{i} - ax_{i} - b)^{2}$$
#
# $$\nabla_{a}{L} = \frac{-2}{n}\sum_{i = 0}^{i =n} (y_{i} - ax_{i} - b)(x_{i})$$
#
# $$\nabla_{b}{L} = \frac{-2}{n}\sum_{i = 0}^{i =n} (y_{i} - ax_{i} - b)$$
#
# I will use the above relations to compute the gradient function required.

# %%
## Gradient function for y = ax + b

def gradient_gd(Y, X, w, tol = 1e-6):
    n = len(X)
    Y_pred = w[0]*X + w[1] ## Stores the predictions
    err = Y - Y_pred
    da = (-2/n) * np.dot(err, X)
    db = (-2/n) * np.sum(err)
    
    return np.array([da, db])

# %% [markdown]
# ## Part 1(c)

# %%
## Generating artificial data 

np.random.seed(0)
X = 2.5 * np.random.randn(10000) + 1.5
res = 1.5 * np.random.randn(10000)
y = 2 + 0.3 * X + res

plt.scatter(X, y)
plt.show()

# %%
## Custom function to compute the MSE Loss
def cost(X, Y, a, b):
    Y_pred = a*X + b
    err = Y - Y_pred
    return(np.square(err).mean())

# %%
## Performing Gradient Descent algorithm for the above dataset

## Custom function to do the gradient descent algorithm (customized just a bit to get time of execution as well)
def my_gradient_descent(X, y, init_, lr, n_iters, tol = 1e-6):
    begin = time.time() # For measuring the time taken to run
    w = init_
    
    for _ in range(n_iters):
        
        ## Computing gradient
        delta = -lr*gradient_gd(y, X, w)
        
        if np.all(np.abs(delta) <= tol):
            break
        
        ## Updating the variables
        w += delta
        
    end = time.time()
    return (w[0], w[1], end - begin)

## Choosing starting parameters: 

a = 0 
b = 0

## Trying different sets of lr, n_iters
lr = 0.01
n_iters = 1000

(a, b, dur) = my_gradient_descent(X, y, np.zeros(2), lr, n_iters)
print(a, b, dur)

(a, b, dur) = my_gradient_descent(X, y, np.zeros(2), 0.02, n_iters)
print(a, b, dur)

(a, b, dur) = my_gradient_descent(X, y, np.zeros(2), 0.01, 2000)
print(a, b, dur)

(a, b, dur) = my_gradient_descent(X, y, np.zeros(2), 0.02, 2000)
print(a, b, dur)

(a, b, dur) = my_gradient_descent(X, y, np.zeros(2), 0.05, n_iters)
print(a, b, dur)
# Out:
# 0.2953318623386959 2.02321971821676 0.02791619300842285
# 0.2953251337809687 2.023254387876724 0.013792991638183594
# 0.2953318623386959 2.02321971821676 0.02875351905822754
# 0.2953251337809687 2.023254387876724 0.014250993728637695
# 0.2953211556179034 2.0232748858149665 0.006213188171386719

# %%
## Function that computes error list as well (takes more time due to invocation of the cost function)

def my_gradient_descent_err(X, y, init_, lr, n_iters, tol = 1e-6):
    begin = time.time() # For measuring the time taken to run
    w = init_
    
    ## Stores the error after each iteration
    err_list = [] 
    
    for i in range(n_iters):
        err_list.append(cost(X, y, w[0], w[1]))
        
        ## Computing gradient
        delta = -lr*gradient_gd(y, X, w)
        
        if np.all(np.abs(delta) <= tol):
            break
        
        ## Updating the variables
        w += delta
        
    end = time.time()
    return (w[0], w[1], end - begin, err_list)


## Plotting the loss function for lr = 0.01 and finding optimal time
## by looking at how many iterations to stop at
a, b, _, errors = my_gradient_descent_err(X, y, np.zeros(2), 0.01, 1000)
print(a, b, errors[-1])

plt.plot(errors, "r-")
plt.xlabel("Number of iterations")
plt.ylabel("Cost")
plt.show()
# Out:
# 0.2953318623386959 2.02321971821676 2.2187210129608617

# %% [markdown]
# We can see that the loss function isn't changing much after around 400 iterations, so we can safely take the number of iterations to be around 400 and compute the average best time taken by normal gradient descent.

# %%
## Computing the average time taken for lr = 0.01 and 400 iterations over 50 runs

tot_time = 0
for i in range(50):
    a, b, dur = my_gradient_descent(X, y, np.zeros(2), 0.01, 400)
    tot_time = tot_time + dur
    
print("Average time taken: " + str(tot_time/50))
# Out:
# Average time taken: 0.014998021125793458

# %% [markdown]
# ## Part 1(d)
#
# In this part, we were asked to write a mini-batch sgd of our own. While writing the code for it, the main bottleneck I felt was the shuffling the dataset to get the batches. Hence to get the maximum out of one single shuffle, I am making multiple mini-batches from one sorting of the indices. And for this reason, I have chosen batch sizes which are divisors of 10,000 (number of data points).

# %%
## Implementing mini-batch gradient descent (Changing the provided template slightly)

def mini_batch_sgd(y, X, init_, lr, n_iters, batch_size = 50, tol = 1e-6):
    
    ## Setting the seed for reproducibility
    np.random.seed(0)
    
    ## Measuring time taken to run as well
    begin = time.time()
    w = init_
    n = len(y)
    
    for _ in range(n_iters):
        
        ## Shuffling the initial dataset randomly for making mini-batches
        index_list = np.random.choice(n, batch_size)
        
        ## Making new batches with each batch size equal to provided batch_size
        X_mini = X[index_list]
        y_mini = y[index_list]

        ## Computing gradients for one mini batch
        delta = -lr*gradient_gd(y_mini, X_mini, w)

        if np.all(np.abs(delta) <= tol):
            break

        ## Updating the parameters according to the computed gradient
        w += delta
            
    end = time.time()
    return (w[0], w[1], end - begin)

# %%
## Implementing mini-batch gradient descent with error calculation inside, which leads to more running time

def mini_batch_sgd_err(y, X, init_, lr, n_iters, batch_size = 50, tol = 1e-6):
    
    ## Setting the seed for reproducibility
    np.random.seed(0)
    
    ## Measuring time taken to run as well
    begin = time.time()
    w = init_
    n = len(y)
    
    ## Error list for storing errors
    error_list = []
    
    for _ in range(n_iters):
        error_list.append(cost(X, y, w[0], w[1]))
        
        ## Shuffling the initial dataset randomly for making mini-batches
        index_list = np.random.choice(n, batch_size)
        
        ## Making new batches with each batch size equal to provided batch_size
        X_mini = X[index_list]
        y_mini = y[index_list]

        ## Computing gradients for one mini batch
        delta = -lr*gradient_gd(y_mini, X_mini, w)

        if np.all(np.abs(delta) <= tol):
            break

        ## Updating the parameters according to the computed gradient
        w += delta
            
    end = time.time()
    return (w[0], w[1], end - begin, error_list)

# %% [markdown]
# I will test below with some of the batch sizes. I have started with 1000 iterations for all of them and stopped at the place when there is no visible changes in the loss function graph, which means we are satisfied with this result. So, the number of iterations in each cell below is chosen such that the model would have converged to it's optimal value.

# %%
## Computing the average time taken for lr = 0.01 and 500 iterations for 100 mini-batch size over 50 runs

tot_time = 0
for i in range(50):
    a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 500, 100)
    tot_time = tot_time + dur 
    
print("Average time taken by mini-batch gradient descent of size 100: " + str(tot_time/50))

a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 500, 100)
print(a, b)

## Printing the loss function for this batch size as well

a, b, dur, errors = mini_batch_sgd_err(y, X, np.zeros(2), 0.01, 500, 100)
print(a, b, dur, errors[-1])

plt.plot(errors, "r-")
plt.xlabel("Number of iterations")
plt.ylabel("Cost")
plt.show()
# Out:
# Average time taken by mini-batch gradient descent of size 100: 0.020496621131896972
# 0.2844106694660944 2.0366817327926596
# 0.2844106694660944 2.0366817327926596 0.04844856262207031 2.2195589467899812

# %%
## Computing the average time taken for lr = 0.01 and 500 iterations for 500 mini-batch size over 50 runs

tot_time = 0
for i in range(50):
    a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 500, 500)
    tot_time = tot_time + dur 
    
print("Average time taken by mini-batch gradient descent of size 500: " + str(tot_time/50))

a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 500, 500)
print(a, b)

## Printing the loss function for this batch size as well

a, b, dur, errors = mini_batch_sgd_err(y, X, np.zeros(2), 0.01, 500, 500)
print(a, b, dur, errors[-1])

plt.plot(errors, "r-")
plt.xlabel("Number of iterations")
plt.ylabel("Cost")
plt.show()
# Out:
# Average time taken by mini-batch gradient descent of size 500: 0.025965094566345215
# 0.289228103398626 2.0137331717432176
# 0.289228103398626 2.0137331717432176 0.042463064193725586 2.2189097613619824

# %%
## Computing the average time taken for lr = 0.01 and 500 iterations for 1000 mini-batch size over 50 runs

tot_time = 0
for i in range(50):
    a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 500, 1000)
    tot_time = tot_time + dur 
    
print("Average time taken by mini-batch gradient descent of size 1000: " + str(tot_time/50))

a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 500, 1000)
print(a, b)

## Printing the loss function for this batch size as well

a, b, dur, errors = mini_batch_sgd_err(y, X, np.zeros(2), 0.01, 500, 1000)
print(a, b, dur, errors[-1])

plt.plot(errors, "r-")
plt.xlabel("Number of iterations")
plt.ylabel("Cost")
plt.show()
# Out:
# Average time taken by mini-batch gradient descent of size 1000: 0.03330087184906006
# 0.2986938120147291 2.019787439782311
# 0.2986938120147291 2.019787439782311 0.051668405532836914 2.2189560042754795

# %%
## Computing the average time taken for lr = 0.01 and 500 iterations for 5000 mini-batch size over 50 runs

tot_time = 0
for i in range(50):
    a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 500, 5000)
    tot_time = tot_time + dur 
    
print("Average time taken by mini-batch gradient descent of size 5000: " + str(tot_time/50))

a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 500, 5000)
print(a, b)

## Printing the loss function for this batch size as well

a, b, dur, errors = mini_batch_sgd_err(y, X, np.zeros(2), 0.01, 500, 5000)
print(a, b, dur, errors[-1])

plt.plot(errors, "r-")
plt.xlabel("Number of iterations")
plt.ylabel("Cost")
plt.show()
# Out:
# Average time taken by mini-batch gradient descent of size 5000: 0.06886281967163085
# 0.29769894507177025 2.0187675824238815
# 0.29769894507177025 2.0187675824238815 0.09241700172424316 2.218747812228915

# %%
## Computing the average time taken for lr = 0.01 and 1000 iterations for 10 mini-batch size over 50 runs

tot_time = 0
for i in range(50):
    a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 1000, 10)
    tot_time = tot_time + dur 
    
print("Average time taken by mini-batch gradient descent of size 10: " + str(tot_time/50))

a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 1000, 10)
print(a, b)

## Printing the loss function for this batch size as well

a, b, dur, errors = mini_batch_sgd_err(y, X, np.zeros(2), 0.01, 1000, 10)
print(a, b, dur, errors[-1])

plt.plot(errors, "r-")
plt.xlabel("Number of iterations")
plt.ylabel("Cost")
plt.show()
# Out:
# Average time taken by mini-batch gradient descent of size 10: 0.04452425479888916
# 0.28657243119655595 2.0668977508025907
# 0.28657243119655595 2.0668977508025907 0.0801396369934082 2.2201597131548225

# %%
## Computing the average time taken for lr = 0.01 and 1000 iterations for 50 mini-batch size over 50 runs

tot_time = 0
for i in range(50):
    a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 1000, 50)
    tot_time = tot_time + dur 
    
print("Average time taken by mini-batch gradient descent of size 50: " + str(tot_time/50))

a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 1000, 50)
print(a, b)

## Printing the loss function for this batch size as well

a, b, dur, errors = mini_batch_sgd_err(y, X, np.zeros(2), 0.01, 1000, 50)
print(a, b, dur, errors[-1])

plt.plot(errors, "r-")
plt.xlabel("Number of iterations")
plt.ylabel("Cost")
plt.show()
# Out:
# Average time taken by mini-batch gradient descent of size 50: 0.04099833011627197
# 0.2647002370151469 2.0420752889843987
# 0.2647002370151469 2.0420752889843987 0.07444167137145996 2.2194007669366926

# %% [markdown]
# From the above graphs, we can infer the best batch size is the one which takes minimum time and converges to a low loss value. Clearly, it is the batch_size of 100, since it's execution time is lower (than the ones with higher batch size) and it coverges within 500 iterations (while 10 and 50, do not). Let us further investigate a bit more.

# %%
## Plotting the loss function for a bad batch size (10)

a, b, dur, errors = mini_batch_sgd_err(y, X, np.zeros(2), 0.01, 1000, 10)
print(a, b, dur, errors[-1])

plt.plot(errors, "r-")
plt.xlabel("Number of iterations")
plt.ylabel("Cost")
plt.show()
# Out:
# 0.28657243119655595 2.0668977508025907 0.07937479019165039 2.2201597131548225

# %% [markdown]
# We can see that keeping the batch size small leads to more fluctuations and hence it becomes difficult to converge to the local optima.

# %%
## Plotting the loss function for a good batch size (100)

a, b, dur, errors = mini_batch_sgd_err(y, X, np.zeros(2), 0.01, 400, 500)
print(a, b, dur, errors[-1])

plt.plot(errors, "r-")
plt.xlabel("Number of iterations")
plt.ylabel("Cost")
plt.show()
# Out:
# 0.29108192835116214 2.0052942685923503 0.04849839210510254 2.2194834591056023

# %%
## Computing the average time taken for lr = 0.01 and 400 iterations for 100 mini-batch size over 50 runs

tot_time = 0
for i in range(50):
    a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 400, 100)
    tot_time = tot_time + dur 
    
print("Average time taken by best mini-batch gradient descent: " + str(tot_time/50))
# Out:
# Average time taken by best mini-batch gradient descent: 0.016799359321594237

# %% [markdown]
# ## Part 1(e)

# %%
## Implementing the simple SGD (1 batch size)

## Computing the average time taken for lr = 0.01 and 400 iterations for 1 mini-batch size over 50 runs

tot_time = 0
for i in range(50):
    a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 400, 1)
    tot_time = tot_time + dur 
    
print("Average time taken by mini-batch gradient descent of size 1: " + str(tot_time/50))

a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 400, 1)
print(a, b)

## Printing the loss function for this batch size as well

a, b, dur, errors = mini_batch_sgd_err(y, X, np.zeros(2), 0.01, 500, 1)
print(a, b, dur, errors[-1])

plt.plot(errors, "r-")
plt.xlabel("Number of iterations")
plt.ylabel("Cost")
plt.show()
# Out:
# Average time taken by mini-batch gradient descent of size 1: 0.015973773002624512
# 0.23238752897726744 1.895583899133259
# 0.30598357342642984 2.0237886487783148 0.03676724433898926 2.222364617607371

# %%
## Calculating time taken by SGD to reach the optimal region (i.e. around 250 iterations)

tot_time = 0
for i in range(50):
    a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 250, 1)
    tot_time = tot_time + dur 
    
print("Average time taken by mini-batch gradient descent of size 1: " + str(tot_time/50))

a, b, dur = mini_batch_sgd(y, X, np.zeros(2), 0.01, 250, 1)
print(a, b)
# Out:
# Average time taken by mini-batch gradient descent of size 1: 0.011471166610717773
# 0.3221686616180755 1.7346819904357824

# %% [markdown]
# In this part, we were asked to discuss about our findings implementing the different gradient descent algorithms. As can be seen in the code, the normal Gradient Descent took around 0.014 - 0.015 seconds with learning rate = 0.01 on average after stopping at appropriate position when the loss function is no more getting reduced.
#
# On implementing mini-batch gradient descent algorithm, I observed that taking different batch sizes actually lead to diffrent answers, though the value of cost function varied only slightly, but still they had different loss plots, which might be because smaller batch sizes may be oscillating quite a lot and hence not converging. While working with different mini-batch sizes I found that batch size of 100 was optimal in the sense that, it converged in the lesser number of iterations than the ones of smaller size and took less time than the ones with higher batch size. I also found the error at the end of the algorithm, for this batch size comparable to the other lowest losses. On finding the average time taken over 500 iterations, the time was found to be 0.016-0.017 sec, which is quite comparable with the normal gradient descent.
#
# Even though the gradient calculation step in the mini-batch SGD is less costly, but still due to the overhead of shuffling the dataset, the final time taken to converge is around same or slightly more than the simple gradient descent.
#
# Another thing to note was that the normal gradient descent actually converges to tolerance less than 1e-6, in around 700 iterations, while mini-batch and sgd didn't. This shows that converging nature of normal gradient descent was better.
#
# On comparing the SGD (1-batch) with the normal gradient descent, I found that SGD performs better in terms of the fact that it reaches the optimal region very fast (around 200 iterations as seen in the loss plot) in around 0.01s. However, we can see that the error function is not that well optimised in this case as the weights will keep oscillating there. Often, in most cases, the close approximation is sufficient enough and that's when SGD will work better than normal gradient descent.
#
# Another thing to note with respect to SGD was that it took more time to complete the gradient descent than some larger batches. This might be due to the impact of shuffling inside the function.

# %% [markdown]
# # Question 2
#
# This question was an extension of the problem asked in the Midsem and asked us to compute some of the probabilities. I will complete both the subparts below.

# %% [markdown]
# (a) In this part, we were asked to find the probability of the event that a person has both cold and fever. Let $C$ denote the event that person has a cold and $F$ denote the event that person has a fever. Then using the rules of conditional probability,
#
# $$P(C, L) = P(F | C) \cdot P(C)$$
#
# We also know that $P(C) = 0.02$ and $P(F | C) = 0.307$. Hence
#
# $$P(C, L) = 0.307 \cdot 0.02 = 0.00614$$

# %% [markdown]
# (b) Let $Co$ denote the event that a person has a cough. In this problem we are asked to find out the probability of the event $C | Co$. Using bayes theorem, we have that
#
# $$P(C | Co) = \frac{P(Co | C) \cdot P(C)}{P(Co)}$$
#
# We know that $P(C) = 0.02$, let us first calculate the probability of $Co$. Since we are given the conditional probability of the event $Co$ under two events, we will use the law of total probability here and write the following (assuming $L$ denotes the event of having a lung disease)
#
# $$P(Co) = P(Co, C, L) + P(Co, C, \bar{L}) + P(Co, \bar{C}, L), P(Co, \bar{C}, \bar{L})$$
#
# Let's calculate the probability of event $L$ now. Let $S$ denote the event that someone smokes. We are given that $P(S) = 0.2$. Using law of total probability, we have
#
# $$P(L) = P(L, S) + P(L, \bar{S})$$
#
# $$P(L) = P(L|S)\cdot P(S) + P(L|\bar{S}) \cdot P(\bar{S})$$
#
# $$P(L) = (0.1009) \cdot (0.2) + (0.001) \cdot (0.8)$$
#
# $$P(L) = 0.02098$$
#
# Now, we can calculate $P(Co)$ as follows
#
# $$P(Co) = P(Co | C, L) \cdot P(C, L) + P(Co | C, \bar{L}) \cdot P(C, \bar{L}) + P(Co | \bar{C}, L) \cdot P(\bar{C}, L) + P(Co | \bar{C}, \bar{L}) \cdot P(\bar{C}, \bar{L})$$
#
# Now, since $C$ and $L$ are independent, we can separate the probabilities and write
#
# $$P(Co) = (0.7525)\cdot(0.02)\cdot(0.02098) + (0.505)\cdot(0.98)\cdot(0.02098) + (0.505)\cdot(0.02)\cdot(0.97902) + (0.01)\cdot(0.98)\cdot(0.97902)$$
#
# $$P(Co) = 0.03018$$
#
# Now, what's left to calculate is $P(Co | C)$. Using the fact that $C$ and $L$ are independent and using the law of total probability, we can write (Proof given in the end).
#
# $$P(Co | C) = P(Co | C, L) \cdot P(L) + P(Co | C, \bar{L}) \cdot P(\bar{L})$$
#
# $$P(Co | C) = (0.7525) \cdot (0.02098) + (0.505) \cdot (0.97902)$$
#
# $$P(Co | C) = 0.51019$$
#
# Hence, now substituting all of them, we get
#
# $$P(C | Co) = \frac{P(Co | C) \cdot P(C)}{P(Co)}$$
#
# $$P(C | Co) = \frac{0.51019 \cdot 0.02}{0.03018}$$
#
# $$P(C | Co) = 0.338$$
#
# ### Proof of fact used above:
#
# Claim: If $b$ and $c$ are independent events and $a$ is another event, then we can write
#
# $$P(a\ |\ b) = P(a\ |\ b, c)\cdot P(c) + P(a\ |\ b, \bar{c})\cdot P(\bar{c})$$
#
# Proof:
#
# $$P(a\ |\ b, c)\cdot P(c) = \frac{P(a, b, c)}{P(b, c)} \cdot P(c) = \frac{P(a, b, c)}{P(b)\cdot P(c)}\cdot P(c)$$
#
# $$P(a\ |\ b, c)\cdot P(c) = \frac{P(a, b, c)}{P(b)}$$
#
# Similarly
#
# $$P(a\ |\ b, \bar{c})\cdot P(\bar{c}) = \frac{P(a, b, \bar{c})}{P(b)}$$
#
# Adding these two we get
#
# $$P(a\ |\ b, c)\cdot P(c) + P(a\ |\ b, \bar{c})\cdot P(\bar{c}) = \frac{P(a, b, c)}{P(b)} + \frac{P(a, b, \bar{c})}{P(b)}$$
#
# Now, applying law of total probability, this becomes
#
# $$$P(a\ |\ b, c)\cdot P(c) + P(a\ |\ b, \bar{c})\cdot P(\bar{c}) = \frac{P(a, b)}{P(b)} = P(a | b)$$

# %% [markdown]
# # Question 3
#
# In this problem we were asked to derive the MLE estimator for the multinomial k-sided distribution. I have provided the derivation below.

# %% [markdown]
# We will first write the PMF of the multinomial distribution. We will first characterize the distribution in the following way. Consider $n$ items to be put into $k$ bins and probability of $i^{th}$ bin being selected is $p_{i}$. Let $x_{1}, x_{2} \dots x_{n}$ denote the count of items in each bin. Then, we get the PMF of this as follows
#
# $$f(x_{1}, x_{2} \dots x_{k} | p_{1} \dots p_{k}) = \frac{n!}{\prod x_{i}!} \prod p_{i}^{x_{i}}$$
#
# This characterization is under the implicit constraints that $\sum p_{i} = 1$, $p_{i} \geq 0$ and $\sum x_{i} = n$.
#
# The negative log-likelihood of the PMF can be written as follows
#
# $$l(p_{1}, p_{2} \dots p_{k} | x_{1} \dots x_{k}) = -log(n!) + \sum_{i = 1}^{k} log(x_{i}!) - \sum_{i = 1}^{k} x_{i}log{p_{i}}$$
#
# Thus, we want to maximise this likelihood under the constraints $\sum p_{i} = 1$, $p_{i} \geq 0$. Thus, on introducing the lagrangian multipliers for these constraints we will get our optimization problem as follows
#
# $$\mathcal{L} = \min_{p_{i}}\left(\max_{\alpha_{i} \geq 0, \beta} \left(-log(n!) + \sum_{i = 1}^{k} log(x_{i}!) - \sum_{i = 1}^{k} x_{i}log{p_{i}} - \sum_{i = 1}^{k} \alpha_{i}p_{i} + \beta\cdot\left(\sum_{i = 1}^{k}{p_i} - 1\right)\right)\right)$$
#
# We will first transform it into the dual problem and then solve the optimization problem
#
# $$\mathcal{L} = \max_{\alpha_{i} \geq 0, \beta}\left(\min_{p_{i}} \left(-log(n!) + \sum_{i = 1}^{k} log(x_{i}!) - \sum_{i = 1}^{k} x_{i}log{p_{i}} - \sum_{i = 1}^{k} \alpha_{i}p_{i} + \beta\cdot\left(\sum_{i = 1}^{k}{p_i} - 1\right)\right)\right)$$
#
# For solving the inner problem, we will differentiate the function partially wrt $\textbf{p}$ first and then optimise the outer problem.
# On differentiating and equating it to zero with respect to each of the $p_{i}$, we get
#
# $$\frac{-x_{i}}{p_{i}} - \alpha_{i} + \beta = 0$$
#
# $$p_{i} = \frac{x_{i}}{\beta - \alpha_{i}} \forall i$$
#
# Putting it back in the original problem, we get
#
# $$\mathcal{L} = \max_{\alpha_{i} \geq 0, \beta}\left(-log(n!) - \sum x_{i} log\left(\frac{x_i}{\beta - \alpha_{i}}\right) - \sum \frac{\alpha_{i}x_{i}}{\beta - \alpha_{i}} + \beta\left(\frac{\sum x_{i}}{\beta - \alpha_{i}} - 1\right)\right)$$
#
# On simplifying and removing constants the problem remains to maximise this
#
# $$\max_{\alpha_{i} \geq 0, \beta}\left(\sum x_{i} log\left(\frac{x_i}{\beta - \alpha_{i}}\right) - \beta\right)$$
#
# Notice that to maximize the above equation, we need to minimise the value of $\alpha_{i}$s. Hence for all $i$, $\alpha_{i} = 0$. Now, differentiating wrt $\beta$ and setting it to $0$, we get
#
# $$\frac{\sum x_{i}}{\beta} - 1 = 0$$
#
# $$\beta = \sum x_{i} = n$$
#
# Hence, after putting it into the above obtained relation, we get that
#
# $$p_{i}^{MLE} = \frac{x_{i}}{\beta - \alpha_{i}} = \frac{x_{i}}{n} \forall i$$
#
# This is the MLE estimate obtained for the multinomial k-sided distribution.
